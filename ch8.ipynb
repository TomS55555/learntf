# %%
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2024-05-07 07:53:22.975157: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-07 07:53:23.274069: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
inputs = keras.Input(shape=(28,28,1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# 2024-05-07 07:53:26.257092: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.295844: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.296128: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.299370: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.299614: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.299765: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.357233: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.357329: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.357390: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-07 07:53:26.357625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5811 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.datasets import mnist 
import numpy as np 

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1)).astype(np.float32) / 255.0
test_images = test_images.reshape((-1, 28, 28, 1)).astype(np.float32) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.compile(optimizer='rmsprop',
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715068413.078266     101 service.cc:145] XLA service 0x769a68006870 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1715068413.078290     101 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2024-05-07 07:53:33.101207: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-07 07:53:33.200697: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# 144/938 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6745 - loss: 0.9858
# I0000 00:00:1715068414.783900     101 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8813 - loss: 0.3690
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9847 - loss: 0.0497
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9908 - loss: 0.0292
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0218
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9952 - loss: 0.0170
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9873 - loss: 0.0320
# Test accuracy: 0.991100013256073

# %%
test_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
from tensorflow import keras 
from tensorflow.keras import layers 

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
from tensorflow.keras.utils import image_dataset_from_directory
from pathlib import Path
base_dir = Path("cats_vs_dogs_small")

train_dataset = image_dataset_from_directory(
    base_dir / "train",
    image_size=(180,180),
    batch_size=32
)
validation_dataset = image_dataset_from_directory(
    base_dir / "validation",
    image_size=(180,180),
    batch_size=32
)
test_dataset = image_dataset_from_directory(
    base_dir / "test",
    image_size=(180,180),
    batch_size=32
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape: ", data_batch.shape)
    print("labels batch shape: ", labels_batch.shape)
    break
# Out:
# data batch shape:  (32, 180, 180, 3)
# labels batch shape:  (32,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.4857 - loss: 0.7915 - val_accuracy: 0.5000 - val_loss: 0.7217
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4946 - loss: 0.6999 - val_accuracy: 0.5030 - val_loss: 0.6919
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5203 - loss: 0.6938 - val_accuracy: 0.5000 - val_loss: 0.6955
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5394 - loss: 0.6881 - val_accuracy: 0.6340 - val_loss: 0.6483
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.6479 - loss: 0.6561 - val_accuracy: 0.6380 - val_loss: 0.6190
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6839 - loss: 0.6122 - val_accuracy: 0.6330 - val_loss: 0.6494
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6951 - loss: 0.5817 - val_accuracy: 0.6820 - val_loss: 0.5761
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7087 - loss: 0.5579 - val_accuracy: 0.6790 - val_loss: 0.6087
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7387 - loss: 0.5380 - val_accuracy: 0.6840 - val_loss: 0.6017
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7584 - loss: 0.5175 - val_accuracy: 0.6680 - val_loss: 0.6154
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7866 - loss: 0.4546 - val_accuracy: 0.7280 - val_loss: 0.5755
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8062 - loss: 0.4381 - val_accuracy: 0.6560 - val_loss: 0.7525
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8236 - loss: 0.3887 - val_accuracy: 0.6960 - val_loss: 0.7421
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8555 - loss: 0.3242 - val_accuracy: 0.7390 - val_loss: 0.6610
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8967 - loss: 0.2593 - val_accuracy: 0.7340 - val_loss: 0.7219
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9032 - loss: 0.2245 - val_accuracy: 0.7310 - val_loss: 0.7796
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9434 - loss: 0.1449 - val_accuracy: 0.7350 - val_loss: 0.9686
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9474 - loss: 0.1344 - val_accuracy: 0.7080 - val_loss: 0.9822
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9530 - loss: 0.1304 - val_accuracy: 0.7260 - val_loss: 1.2825
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9627 - loss: 0.0938 - val_accuracy: 0.7360 - val_loss: 1.2756
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9610 - loss: 0.0983 - val_accuracy: 0.7070 - val_loss: 1.5369
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9822 - loss: 0.0560 - val_accuracy: 0.7260 - val_loss: 1.6592
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9795 - loss: 0.0556 - val_accuracy: 0.7380 - val_loss: 1.5349
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9883 - loss: 0.0419 - val_accuracy: 0.7500 - val_loss: 1.4241
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9827 - loss: 0.0498 - val_accuracy: 0.7510 - val_loss: 1.6994
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9855 - loss: 0.0469 - val_accuracy: 0.7370 - val_loss: 1.7606
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9769 - loss: 0.0878 - val_accuracy: 0.7480 - val_loss: 1.7156
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9896 - loss: 0.0337 - val_accuracy: 0.7100 - val_loss: 2.0613
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9756 - loss: 0.0989 - val_accuracy: 0.7020 - val_loss: 2.3233
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9815 - loss: 0.0488 - val_accuracy: 0.7330 - val_loss: 2.0302

# %%
import matplotlib.pyplot as plt 
def plot_history(history):
    history_dict = history.history
    fig, axs = plt.subplots(1,2, figsize=(14,6))
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    epochs = range(1, len(loss_values)+1)
    axs[0].plot(epochs, loss_values, 'bo', label="Training loss")
    axs[0].plot(epochs, val_loss_values, 'b', label="Validation loss")
    axs[0].set_title("Training and validation loss")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Loss")

    axs[1].plot(epochs, history_dict['accuracy'], 'bo', label="Training accuracy")
    axs[1].plot(epochs, history_dict['val_accuracy'], 'b', label='Validation accuracy')
    axs[1].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epochs")
    axs[1].set_title("Training and validation accuracy")
    plt.legend()
    plt.show()
plot_history(history)

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7111 - loss: 0.6560
# Test accuracy: 0.715499997138977

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2)
])

plt.figure(figsize=(10,10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        print(augmented_images.shape)
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# (32, 180, 180, 3)
# 2024-05-07 08:35:45.412819: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# now lets also add dropout to our model

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_2 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.5126 - loss: 0.7060 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.4788 - loss: 0.6948 - val_accuracy: 0.6210 - val_loss: 0.6904
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5384 - loss: 0.6952 - val_accuracy: 0.5000 - val_loss: 0.7215
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5875 - loss: 0.6899 - val_accuracy: 0.5170 - val_loss: 0.6839
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5838 - loss: 0.6776 - val_accuracy: 0.6220 - val_loss: 0.6366
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6629 - loss: 0.6402 - val_accuracy: 0.5910 - val_loss: 0.6806
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6605 - loss: 0.6106 - val_accuracy: 0.6780 - val_loss: 0.6173
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6973 - loss: 0.6015 - val_accuracy: 0.6190 - val_loss: 0.6890
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7013 - loss: 0.5888 - val_accuracy: 0.7030 - val_loss: 0.5773
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7143 - loss: 0.5681 - val_accuracy: 0.6840 - val_loss: 0.5848
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7081 - loss: 0.5781 - val_accuracy: 0.6950 - val_loss: 0.6109
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6998 - loss: 0.5660 - val_accuracy: 0.6870 - val_loss: 0.6016
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7202 - loss: 0.5594 - val_accuracy: 0.6470 - val_loss: 0.7145
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7021 - loss: 0.5643 - val_accuracy: 0.7450 - val_loss: 0.5125
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7208 - loss: 0.5380 - val_accuracy: 0.7040 - val_loss: 0.6043
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7427 - loss: 0.5077 - val_accuracy: 0.7700 - val_loss: 0.4868
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7521 - loss: 0.5091 - val_accuracy: 0.7030 - val_loss: 0.5481
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7399 - loss: 0.5054 - val_accuracy: 0.7560 - val_loss: 0.5236
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7457 - loss: 0.5228 - val_accuracy: 0.6940 - val_loss: 0.5787
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7588 - loss: 0.5091 - val_accuracy: 0.7680 - val_loss: 0.4947
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.7645 - loss: 0.4826 - val_accuracy: 0.7750 - val_loss: 0.4697
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7796 - loss: 0.4666 - val_accuracy: 0.7470 - val_loss: 0.5100
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7893 - loss: 0.4446 - val_accuracy: 0.7910 - val_loss: 0.4637
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8223 - loss: 0.4251 - val_accuracy: 0.7500 - val_loss: 0.5127
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7873 - loss: 0.4303 - val_accuracy: 0.7690 - val_loss: 0.5332
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8030 - loss: 0.4307 - val_accuracy: 0.7710 - val_loss: 0.4925
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7950 - loss: 0.4521 - val_accuracy: 0.7940 - val_loss: 0.4364
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8093 - loss: 0.4144 - val_accuracy: 0.7390 - val_loss: 0.5466
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7856 - loss: 0.4603 - val_accuracy: 0.8160 - val_loss: 0.4290
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8207 - loss: 0.3903 - val_accuracy: 0.7910 - val_loss: 0.4673
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8471 - loss: 0.3630 - val_accuracy: 0.8190 - val_loss: 0.4311
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8375 - loss: 0.3705 - val_accuracy: 0.7940 - val_loss: 0.4559
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8400 - loss: 0.3573 - val_accuracy: 0.7500 - val_loss: 0.6193
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8464 - loss: 0.3512 - val_accuracy: 0.7760 - val_loss: 0.5654
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8393 - loss: 0.3672 - val_accuracy: 0.8030 - val_loss: 0.4699
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8502 - loss: 0.3331 - val_accuracy: 0.7560 - val_loss: 0.5152
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8462 - loss: 0.3494 - val_accuracy: 0.8280 - val_loss: 0.4338
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8628 - loss: 0.3139 - val_accuracy: 0.8020 - val_loss: 0.5153
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8463 - loss: 0.3579 - val_accuracy: 0.8270 - val_loss: 0.4270
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8491 - loss: 0.3330 - val_accuracy: 0.8260 - val_loss: 0.4746
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8582 - loss: 0.3099 - val_accuracy: 0.7960 - val_loss: 0.4831
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8688 - loss: 0.3008 - val_accuracy: 0.8140 - val_loss: 0.4446
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8685 - loss: 0.3110 - val_accuracy: 0.7740 - val_loss: 0.6162
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8652 - loss: 0.2985 - val_accuracy: 0.7950 - val_loss: 0.5563
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8728 - loss: 0.2989 - val_accuracy: 0.8360 - val_loss: 0.4872
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8771 - loss: 0.2712 - val_accuracy: 0.8300 - val_loss: 0.4505
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8660 - loss: 0.2906 - val_accuracy: 0.8110 - val_loss: 0.4541
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8820 - loss: 0.2683 - val_accuracy: 0.8150 - val_loss: 0.5194
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9006 - loss: 0.2404 - val_accuracy: 0.7770 - val_loss: 0.6825
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8893 - loss: 0.2398 - val_accuracy: 0.8220 - val_loss: 0.4765
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8952 - loss: 0.2500 - val_accuracy: 0.8060 - val_loss: 0.5658
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9055 - loss: 0.2413 - val_accuracy: 0.8070 - val_loss: 0.5556
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9142 - loss: 0.2219 - val_accuracy: 0.8310 - val_loss: 0.5110
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9149 - loss: 0.2216 - val_accuracy: 0.8350 - val_loss: 0.4278
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9067 - loss: 0.2279 - val_accuracy: 0.7670 - val_loss: 0.6565
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9072 - loss: 0.2517 - val_accuracy: 0.8460 - val_loss: 0.4379
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9091 - loss: 0.2362 - val_accuracy: 0.8370 - val_loss: 0.4529
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9156 - loss: 0.2072 - val_accuracy: 0.8020 - val_loss: 0.5502
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9072 - loss: 0.2159 - val_accuracy: 0.8520 - val_loss: 0.4884
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9260 - loss: 0.2006 - val_accuracy: 0.8060 - val_loss: 0.6954
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9048 - loss: 0.2425 - val_accuracy: 0.8470 - val_loss: 0.4439
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9275 - loss: 0.1961 - val_accuracy: 0.8380 - val_loss: 0.5559
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9157 - loss: 0.2239 - val_accuracy: 0.8240 - val_loss: 0.5229
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9177 - loss: 0.2119 - val_accuracy: 0.8530 - val_loss: 0.4777
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9170 - loss: 0.2189 - val_accuracy: 0.8400 - val_loss: 0.4997
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9228 - loss: 0.2010 - val_accuracy: 0.8320 - val_loss: 0.5223
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9131 - loss: 0.2242 - val_accuracy: 0.8430 - val_loss: 0.4552
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9329 - loss: 0.1679 - val_accuracy: 0.8530 - val_loss: 0.4916
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9149 - loss: 0.2055 - val_accuracy: 0.8440 - val_loss: 0.5096
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9385 - loss: 0.1682 - val_accuracy: 0.8170 - val_loss: 0.6934
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9273 - loss: 0.2039 - val_accuracy: 0.8010 - val_loss: 0.7296
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9046 - loss: 0.2335 - val_accuracy: 0.8650 - val_loss: 0.4307
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9314 - loss: 0.1641 - val_accuracy: 0.7750 - val_loss: 0.7999
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9111 - loss: 0.2045 - val_accuracy: 0.7780 - val_loss: 0.7839
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9196 - loss: 0.1865 - val_accuracy: 0.8320 - val_loss: 0.5252
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9400 - loss: 0.1505 - val_accuracy: 0.8360 - val_loss: 0.6417
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9422 - loss: 0.1760 - val_accuracy: 0.8390 - val_loss: 0.5483
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9396 - loss: 0.1396 - val_accuracy: 0.8300 - val_loss: 0.8064
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9301 - loss: 0.1888 - val_accuracy: 0.8440 - val_loss: 0.6038
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9442 - loss: 0.1507 - val_accuracy: 0.8500 - val_loss: 0.7033
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9292 - loss: 0.1940 - val_accuracy: 0.8070 - val_loss: 0.8063
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9469 - loss: 0.1644 - val_accuracy: 0.8370 - val_loss: 0.6190
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9337 - loss: 0.1717 - val_accuracy: 0.8270 - val_loss: 0.7255
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9344 - loss: 0.1799 - val_accuracy: 0.8180 - val_loss: 0.6820
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9462 - loss: 0.1754 - val_accuracy: 0.8390 - val_loss: 0.6940
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9436 - loss: 0.1680 - val_accuracy: 0.8560 - val_loss: 0.5920
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9368 - loss: 0.1728 - val_accuracy: 0.8470 - val_loss: 0.5736
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9403 - loss: 0.1741 - val_accuracy: 0.8530 - val_loss: 0.5457
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9382 - loss: 0.1727 - val_accuracy: 0.8360 - val_loss: 0.5698
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9383 - loss: 0.1622 - val_accuracy: 0.8080 - val_loss: 0.7893
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9383 - loss: 0.1760 - val_accuracy: 0.8420 - val_loss: 0.5287
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9564 - loss: 0.1173 - val_accuracy: 0.8480 - val_loss: 0.5995
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9401 - loss: 0.1669 - val_accuracy: 0.8340 - val_loss: 0.6425
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9432 - loss: 0.1533 - val_accuracy: 0.8490 - val_loss: 0.5981
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9549 - loss: 0.1474 - val_accuracy: 0.8170 - val_loss: 0.7119
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9434 - loss: 0.1852 - val_accuracy: 0.8370 - val_loss: 0.7885
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9494 - loss: 0.1610 - val_accuracy: 0.8430 - val_loss: 0.6469
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9429 - loss: 0.1591 - val_accuracy: 0.8330 - val_loss: 0.7291
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9540 - loss: 0.1460 - val_accuracy: 0.8560 - val_loss: 0.6906
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9509 - loss: 0.1425 - val_accuracy: 0.8240 - val_loss: 0.9106

# %%
plot_history(history)

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8033 - loss: 0.5178
# Test accuracy: 0.8130000233650208

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180,180,3)
)
conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 180, 180, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 180, 180, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 90, 90, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 90, 90, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 90, 90, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 45, 45, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 22, 22, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 5, 5, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
conv_base.trainable = False
print(f"This is the number of trainable weights: {len(conv_base.trainable_weights)}")
# Out:
# This is the number of trainable weights: 0

# %%
inputs = keras.Input(shape=(180,180,3))
x = data_augmentation(inputs)
x = keras.layers.Lambda(
     lambda x: keras.applications.vgg16.preprocess_input(x))(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy", optimizer="rmsprop", metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 5, 5, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │     3,277,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,992,001 (68.63 MB)
#  Trainable params: 3,277,313 (12.50 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="vgg16_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.8179 - loss: 38.9159 - val_accuracy: 0.9530 - val_loss: 6.2719
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9449 - loss: 8.6849 - val_accuracy: 0.9730 - val_loss: 3.6222
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9578 - loss: 5.4337 - val_accuracy: 0.9790 - val_loss: 3.1776
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9613 - loss: 4.0197 - val_accuracy: 0.9700 - val_loss: 4.4454
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9641 - loss: 3.9633 - val_accuracy: 0.9780 - val_loss: 2.3780
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - accuracy: 0.9678 - loss: 3.8310 - val_accuracy: 0.9730 - val_loss: 3.3887
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9623 - loss: 3.4899 - val_accuracy: 0.9620 - val_loss: 7.2957
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9662 - loss: 4.8763 - val_accuracy: 0.9780 - val_loss: 3.6938
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9690 - loss: 3.3331 - val_accuracy: 0.9790 - val_loss: 6.0663
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9690 - loss: 2.6631 - val_accuracy: 0.9700 - val_loss: 6.3513
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9713 - loss: 2.3361 - val_accuracy: 0.9820 - val_loss: 2.9842
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.9701 - loss: 3.2844 - val_accuracy: 0.9760 - val_loss: 3.5058
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9701 - loss: 3.0716 - val_accuracy: 0.9770 - val_loss: 3.4910
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9743 - loss: 2.3965 - val_accuracy: 0.9750 - val_loss: 3.4327
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9790 - loss: 1.7575 - val_accuracy: 0.9810 - val_loss: 2.9144
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.9874 - loss: 0.8983 - val_accuracy: 0.9830 - val_loss: 2.3506
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9833 - loss: 1.2014 - val_accuracy: 0.9740 - val_loss: 3.4637
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9882 - loss: 1.1344 - val_accuracy: 0.9850 - val_loss: 1.8513
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9863 - loss: 1.1090 - val_accuracy: 0.9810 - val_loss: 2.0429
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9827 - loss: 1.5643 - val_accuracy: 0.9810 - val_loss: 2.8816
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9845 - loss: 1.1301 - val_accuracy: 0.9800 - val_loss: 2.9699
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9814 - loss: 1.0885 - val_accuracy: 0.9810 - val_loss: 2.3078
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.9882 - loss: 0.7950 - val_accuracy: 0.9770 - val_loss: 3.3611
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9813 - loss: 1.4841 - val_accuracy: 0.9760 - val_loss: 3.1102
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9868 - loss: 0.6977 - val_accuracy: 0.9710 - val_loss: 3.6537
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9828 - loss: 0.9461 - val_accuracy: 0.9830 - val_loss: 2.2426
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9867 - loss: 0.6812 - val_accuracy: 0.9810 - val_loss: 2.0093
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9897 - loss: 0.3555 - val_accuracy: 0.9770 - val_loss: 2.7553
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9818 - loss: 1.0036 - val_accuracy: 0.9770 - val_loss: 3.3920
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9819 - loss: 1.0823 - val_accuracy: 0.9770 - val_loss: 2.7667
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9850 - loss: 0.5199 - val_accuracy: 0.9760 - val_loss: 3.2111
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9846 - loss: 0.9306 - val_accuracy: 0.9790 - val_loss: 2.6399
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9864 - loss: 0.8975 - val_accuracy: 0.9790 - val_loss: 2.3822
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9905 - loss: 0.4878 - val_accuracy: 0.9750 - val_loss: 2.6540
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9927 - loss: 0.3494 - val_accuracy: 0.9780 - val_loss: 2.2656
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - accuracy: 0.9874 - loss: 0.6859 - val_accuracy: 0.9770 - val_loss: 2.1551
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9835 - loss: 1.0500 - val_accuracy: 0.9780 - val_loss: 2.6254
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9921 - loss: 0.3319 - val_accuracy: 0.9690 - val_loss: 3.1189
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9838 - loss: 0.9958 - val_accuracy: 0.9720 - val_loss: 3.9950
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9817 - loss: 0.9756 - val_accuracy: 0.9770 - val_loss: 2.0035
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9910 - loss: 0.3872 - val_accuracy: 0.9780 - val_loss: 1.8570
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9866 - loss: 0.7636 - val_accuracy: 0.9760 - val_loss: 2.0966
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.9867 - loss: 0.5487 - val_accuracy: 0.9770 - val_loss: 2.1982
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - accuracy: 0.9894 - loss: 0.4168 - val_accuracy: 0.9760 - val_loss: 1.6674
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9929 - loss: 0.3598 - val_accuracy: 0.9750 - val_loss: 2.4372
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9946 - loss: 0.1938 - val_accuracy: 0.9800 - val_loss: 2.3577
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9906 - loss: 0.4027 - val_accuracy: 0.9790 - val_loss: 2.2021
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9875 - loss: 0.7351 - val_accuracy: 0.9730 - val_loss: 3.5321
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9849 - loss: 0.9418 - val_accuracy: 0.9760 - val_loss: 2.3916
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9863 - loss: 0.7685 - val_accuracy: 0.9810 - val_loss: 2.5939

# %%
plot_history(history)
keras.config.enable_unsafe_deserialization()
test_model = keras.models.load_model("vgg16_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 3
#       1 plot_history(history)
#       2 keras.config.enable_unsafe_deserialization()
# ----> 3 test_model = keras.models.load_model("vgg16_with_augmentation.keras")
#       4 test_loss, test_acc = test_model.evaluate(test_dataset)
#       5 print(f"Test accuracy: {test_acc}")
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py:176, in load_model(filepath, custom_objects, compile, safe_mode)
#     173         is_keras_zip = True
#     175 if is_keras_zip:
# --> 176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
#     183     return legacy_h5_format.load_model_from_hdf5(filepath)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:155, in load_model(filepath, custom_objects, compile, safe_mode)
#     153 # Construct the model from the configuration file in the archive.
#     154 with ObjectSharingScope():
# --> 155     model = deserialize_keras_object(
#     156         config_dict, custom_objects, safe_mode=safe_mode
#     157     )
#     159 all_filenames = zf.namelist()
#     160 if _VARS_FNAME + ".h5" in all_filenames:
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/saving/serialization_lib.py:711, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     709 with custom_obj_scope, safe_mode_scope:
#     710     try:
# --> 711         instance = cls.from_config(inner_config)
#     712     except TypeError as e:
#     713         raise TypeError(
#     714             f"{cls} could not be deserialized properly. Please"
#     715             " ensure that components that are Python object"
#    (...)
#     719             f"\n\nconfig={config}.\n\nException encountered: {e}"
#     720         )
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/models/model.py:492, in Model.from_config(cls, config, custom_objects)
#     487 if is_functional_config and revivable_as_functional:
#     488     # Revive Functional model
#     489     # (but not Functional subclasses with a custom __init__)
#     490     from keras.src.models.functional import functional_from_config
# --> 492     return functional_from_config(
#     493         cls, config, custom_objects=custom_objects
#     494     )
#     496 # Either the model has a custom __init__, or the config
#     497 # does not contain all the information necessary to
#     498 # revive a Functional model. This happens when the user creates
#    (...)
#     501 # In this case, we fall back to provide all config into the
#     502 # constructor of the class.
#     503 try:
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:522, in functional_from_config(cls, config, custom_objects)
#     520 node_data = node_data_list[node_index]
#     521 try:
# --> 522     process_node(layer, node_data)
#     524 # If the node does not have all inbound layers
#     525 # available, stop processing and continue later
#     526 except IndexError:
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:466, in functional_from_config.<locals>.process_node(layer, node_data)
#     459 def process_node(layer, node_data):
#     460     """Reconstruct node by linking to inbound layers
#     461
#     462     Args:
#     463         layer: Layer to process
#     464         node_data: List of layer configs
#     465     """
# --> 466     args, kwargs = deserialize_node(node_data, created_layers)
#     467     # Call layer on its inputs, thus creating the node
#     468     # and building the layer if needed.
#     469     layer(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:666, in deserialize_node(node_data, created_layers)
#     663         return inbound_node.output_tensors[inbound_tensor_index]
#     664     return x
# --> 666 args = tree.map_structure(convert_revived_tensor, args)
#     667 kwargs = tree.map_structure(convert_revived_tensor, kwargs)
#     668 return args, kwargs
#
# File /usr/local/lib/python3.11/dist-packages/tree/__init__.py:435, in map_structure(func, *structures, **kwargs)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /usr/local/lib/python3.11/dist-packages/tree/__init__.py:435, in <listcomp>(.0)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:656, in deserialize_node.<locals>.convert_revived_tensor(x)
#     654 inbound_tensor_index = history[2]
#     655 if len(layer._inbound_nodes) <= inbound_node_index:
# --> 656     raise ValueError(
#     657         "Layer node index out of bounds.\n"
#     658         f"inbound_layer = {layer}\n"
#     659         f"inbound_layer._inbound_nodes = {layer._inbound_nodes}\n"
#     660         f"inbound_node_index = {inbound_node_index}"
#     661     )
#     662 inbound_node = layer._inbound_nodes[inbound_node_index]
#     663 return inbound_node.output_tensors[inbound_tensor_index]
#
# ValueError: Layer node index out of bounds.
# inbound_layer = <Sequential name=sequential_1, built=True>
# inbound_layer._inbound_nodes = [<Node operation=<Sequential name=sequential_1, built=True>, id=130413517696656>]
# inbound_node_index = 6

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False
print(f"Number of trainable weights: {conv_base.trainable_weights}")
# Out:
# Number of trainable weights: [<KerasVariable shape=(3, 3, 512, 512), dtype=float32, path=block5_conv1/kernel>, <KerasVariable shape=(512,), dtype=float32, path=block5_conv1/bias>, <KerasVariable shape=(3, 3, 512, 512), dtype=float32, path=block5_conv2/kernel>, <KerasVariable shape=(512,), dtype=float32, path=block5_conv2/bias>, <KerasVariable shape=(3, 3, 512, 512), dtype=float32, path=block5_conv3/kernel>, <KerasVariable shape=(512,), dtype=float32, path=block5_conv3/bias>]

# %%
model.compile(loss="binary_crossentropy", optimizer=keras.optimizers.RMSprop(learning_rate=1e-5), metrics=["accuracy"])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data = validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 157ms/step - accuracy: 0.9951 - loss: 0.2222 - val_accuracy: 0.9780 - val_loss: 2.7541
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9933 - loss: 0.3811 - val_accuracy: 0.9790 - val_loss: 2.2996
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9958 - loss: 0.2319 - val_accuracy: 0.9780 - val_loss: 2.4769
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9950 - loss: 0.1848 - val_accuracy: 0.9760 - val_loss: 2.2676
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9967 - loss: 0.3260 - val_accuracy: 0.9730 - val_loss: 2.4366
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9931 - loss: 0.3343 - val_accuracy: 0.9830 - val_loss: 1.8130
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9850 - loss: 0.5481 - val_accuracy: 0.9820 - val_loss: 1.5096
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9923 - loss: 0.1687 - val_accuracy: 0.9700 - val_loss: 3.5921
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9939 - loss: 0.3219 - val_accuracy: 0.9680 - val_loss: 3.3856
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9909 - loss: 0.5269 - val_accuracy: 0.9770 - val_loss: 2.3783
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9906 - loss: 0.3012 - val_accuracy: 0.9770 - val_loss: 2.1190
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9939 - loss: 0.1916 - val_accuracy: 0.9710 - val_loss: 2.7593
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9889 - loss: 0.4722 - val_accuracy: 0.9730 - val_loss: 2.2726
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9955 - loss: 0.0752 - val_accuracy: 0.9810 - val_loss: 2.5286
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9935 - loss: 0.0823 - val_accuracy: 0.9800 - val_loss: 2.4223
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9935 - loss: 0.1713 - val_accuracy: 0.9770 - val_loss: 2.0164
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9948 - loss: 0.2591 - val_accuracy: 0.9730 - val_loss: 2.4184
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9973 - loss: 0.0798 - val_accuracy: 0.9790 - val_loss: 2.2097
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9975 - loss: 0.0504 - val_accuracy: 0.9750 - val_loss: 2.1768
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9941 - loss: 0.1544 - val_accuracy: 0.9790 - val_loss: 1.8232
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9952 - loss: 0.2315 - val_accuracy: 0.9800 - val_loss: 1.8989
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9995 - loss: 0.0189 - val_accuracy: 0.9700 - val_loss: 3.1433
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9966 - loss: 0.1434 - val_accuracy: 0.9780 - val_loss: 2.0111
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9945 - loss: 0.0886 - val_accuracy: 0.9750 - val_loss: 2.4295
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9983 - loss: 0.0339 - val_accuracy: 0.9740 - val_loss: 2.8903
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9952 - loss: 0.1507 - val_accuracy: 0.9810 - val_loss: 2.0341
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9968 - loss: 0.1019 - val_accuracy: 0.9690 - val_loss: 3.0737
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9945 - loss: 0.1918 - val_accuracy: 0.9790 - val_loss: 2.2369
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9988 - loss: 0.0444 - val_accuracy: 0.9780 - val_loss: 2.2060
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9969 - loss: 0.1087 - val_accuracy: 0.9790 - val_loss: 2.0408

# %%
plot_history(history)
test_model = keras.models.load_model("fine_tuning.keras", save_mode=False)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 plot_history(history)
# ----> 2 test_model = keras.models.load_model("fine_tuning.keras", save_mode=False)
#       3 test_loss, test_acc = test_model.evaluate(test_dataset)
#       4 print(f"Test accuracy: {test_acc}")
#
# TypeError: load_model() got an unexpected keyword argument 'save_mode'
